# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('data.csv', delimiter='^', error_bad_lines=False)

data = data[(data.Пол == 'Ж') | (data.Пол == 'М')] 
del data['удалить']

# %%
data
# Out:
#                                    ФИО Пол  \
# 0            Аввакумова Алина Олеговна   Ж
# 1        Антонова Альбина Владимировна   Ж
# 2           Арсланова Зарина Ленаровна   Ж
# 3             Аухадеев Тимур Ринатович   М
# 4        Ахметзянова Лейсан Габбасовна   Ж
# 5            Бадрутдинов Олег Рауфович   М
# 6            Бикташева Лилия Рамилевна   Ж
# 7            Валеева Гузель Равильевна   Ж
# 8         Гайнуллина Айгуль Равильевна   Ж
# 9        Гайнутдинова Гульшат Флюровна   Ж
# 10        Гайфутдинова Наиля Равилевна   Ж
# 11        Галиева Гульназ Шайхинуровна   Ж
# 12             Галицкая Полина Юрьевна   Ж
# 13             Гафуров Артур Маратович   М
# 14    Гильмутдинова Ильсина Мансуровна   Ж
# 15           Гильфанов Артур Камилевич   М
# 16        Гиниятуллин Камиль Гашикович   М
# 17            Гоголь Феликс Витальевич   М
# 18         Гордеев Александр Сергеевич   М
# 19           Гордеева Карина Андреевна   Ж
# 20      Гурьянов Владимир Владимирович   М
# ...

# %%
print(data.info, '\n')
# Out:
# <bound method DataFrame.info of                                    ФИО Пол  \
# 0            Аввакумова Алина Олеговна   Ж
# 1        Антонова Альбина Владимировна   Ж
# 2           Арсланова Зарина Ленаровна   Ж
# 3             Аухадеев Тимур Ринатович   М
# 4        Ахметзянова Лейсан Габбасовна   Ж
# 5            Бадрутдинов Олег Рауфович   М
# 6            Бикташева Лилия Рамилевна   Ж
# 7            Валеева Гузель Равильевна   Ж
# 8         Гайнуллина Айгуль Равильевна   Ж
# 9        Гайнутдинова Гульшат Флюровна   Ж
# 10        Гайфутдинова Наиля Равилевна   Ж
# 11        Галиева Гульназ Шайхинуровна   Ж
# 12             Галицкая Полина Юрьевна   Ж
# 13             Гафуров Артур Маратович   М
# 14    Гильмутдинова Ильсина Мансуровна   Ж
# 15           Гильфанов Артур Камилевич   М
# 16        Гиниятуллин Камиль Гашикович   М
# 17            Гоголь Феликс Витальевич   М
# 18         Гордеев Александр Сергеевич   М
# 19           Гордеева Карина Андреевна   Ж
# ...

# %%
print(data.shape, '\n')
# Out:
# (7103, 21)

# %%
x = df[df.ФИО == 'Григорян Карен Альбертович']
x
# Out:
#                              ФИО Пол  \
# 378   Григорян Карен Альбертович   М
# 2025  Григорян Карен Альбертович   М
#
#                                           Подразделение  \
# 378   Высшая школа информационных технологий и интел...
# 2025          Институт управления, экономики и финансов
#
#      Классификация направления Наличие Страницы  \
# 378          Технические науки                +
# 2025        Общественные науки                +
#
#                               Знание языков  \
# 378   английский(Самостоятельное владение)
# 2025  английский(Самостоятельное владение)
#
#                                             Образование Квалификация  \
# 378   1994-1999 высшее образование: Казанский госуда...   менеджер;
# 2025  1994-1999 высшее образование: Казанский госуда...   менеджер;
#
#                       Ученые степени  \
# 378   кандидат (экономические науки)
# 2025  кандидат (экономические науки)
#
# ...

# %%
x = df[df.ФИО == 'Нурутдинова Алсу Рафаиловна']
x
# Out:
#                              ФИО Пол  \
# 408  Нурутдинова Алсу Рафаиловна   Ж
#
#                                          Подразделение  \
# 408  Высшая школа информационных технологий и интел...
#
#     Классификация направления Наличие Страницы Знание языков  \
# 408         Технические науки                +          None
#
#                                            Образование Квалификация  \
# 408  2001-2006 высшее образование: Елабужский госуд...         None
#
#                              Ученые степени  \
# 408  кандидат (физико-математические науки)
#
#                                          Специальность  ... Дата защиты  \
# 408   01.01.09 - Дискретная математика и математиче...  ...  20.12.2019
#
#     Ученые звания Наличие прикрепленных файлов Дата рождения  \
# 408          None                            -          None
#
#                            Занимаемые должности Список публикаций в СМИ  \
# ...

# %%
print(df.shape, '\n')
# Out:
# (7103, 21)

# %%
print(data.columns, '\n')
# Out:
# Index(['ФИО', 'Пол', 'Подразделение', 'Классификация направления',
#        'Наличие Страницы', 'Знание языков', 'Образование', 'Квалификация',
#        'Ученые степени', 'Специальность', 'Название диссертации',
#        'Дата защиты', 'Ученые звания', 'Наличие прикрепленных файлов',
#        'Дата рождения', 'Занимаемые должности', 'Список публикаций в СМИ',
#        'Монографии', 'Статьи', 'Тезисы и материалы конференций',
#        'Учебники и учебные пособия'],
#       dtype='object')

# %%
quantity = data['Пол'].value_counts()
print(quantity[0:2])
# Out:
# Ж    4380
# М    2723
# Name: Пол, dtype: int64

# %%
x = quantity[0] + quantity[1]
print('Соотношение женщин в институте', quantity[0] / x)
print('Соотношение мужчин в институте', quantity[1] / x)
# Out:
# Соотношение женщин в институте 0.616640855976348
# Соотношение мужчин в институте 0.38335914402365195

# %%
quantity = data['Наличие Страницы'].value_counts()
print(quantity[0:2])
# Out:
# +    4748
# -    2355
# Name: Наличие Страницы, dtype: int64

# %%
x = quantity[0] + quantity[1]
print('Соотношение преподавателей со страницами', quantity[0] / x)
print('Соотношение преподавателей без страницами', quantity[1] / x)
# Out:
# Соотношение преподавателей со страницами 0.6684499507250458
# Соотношение преподавателей без страницами 0.33155004927495424

# %%
quantity = data['Классификация направления'].value_counts()
print(quantity[0:4])
# Out:
# Естественные науки    2015
# None                  1610
# Общественные науки    1455
# Технические науки     1352
# Name: Классификация направления, dtype: int64

# %%
quantity = data['Знание языков'].value_counts()
print('Топ 10')
print(quantity[1:11])
# Out:
# Топ 10
# английский(Самостоятельное владение)                                   639
# английский(Свободное владение)                                         470
# английский(Элементарное владение)                                      247
# английский(Пороговый продвинутый уровень)                              124
# английский(Пороговый уровень)                                           55
# английский(Уровень профессионального владения)                          51
# английский(Самостоятельное владение) татарский(Свободное владение)      45
# немецкий(Самостоятельное владение)                                      44
# немецкий(Элементарное владение)                                         41
# английский(Свободное владение) немецкий(Самостоятельное владение)       36
# Name: Знание языков, dtype: int64

# %%
quantity = data['Квалификация'].value_counts()
print(quantity[1:20])
# Out:
# Математик;             94
# Магистр; Бакалавр;     63
# Физик;                 63
# магистр; бакалавр;     58
# Юрист;                 58
# экономист;             49
# специалист;            47
# Экономист;             41
# Химик;                 40
# Радиофизик;            35
# магистр;               31
# юрист;                 29
# Биолог;                29
# врач;                  26
# Бакалавр;              26
# Менеджер;              22
# Магистр;               21
# бакалавр;              19
# физик;                 19
# Name: Квалификация, dtype: int64

# %%
quantity = data['Ученые звания'].value_counts()
print(quantity[1:20])
# Out:
# доцент                  39
# доцент (31.12.2013)     16
# доцент (23.08.2019)     11
# доцент (30.12.2013)     11
# доцент (01.12.2011)      9
# доцент (17.10.2007)      9
# доцент (26.10.2006)      9
# профессор                9
# доцент (17.07.2002)      8
# доцент (19.11.2008)      8
# доцент (10.07.2017)      8
# доцент (19.03.2020)      7
# доцент (13.10.2014)      7
# доцент (18.11.2009)      7
# доцент (20.10.2010)      7
# доцент (16.03.2011)      7
# доцент (15.06.2018)      7
# доцент (29.05.2019)      6
# доцент (14.12.2015)      6
# Name: Ученые звания, dtype: int64

# %%
quantity = data['Дата рождения'].value_counts()
print(quantity[1:40])
# Out:
# 11.05.1989    5
# 06.06.1988    4
# 23.07.1994    4
# 17.03.1983    4
# 13.05.1976    4
# 21.03.1972    4
# 15.08.1953    4
# 17.12.1974    4
# 06.09.1977    4
# 23.05.1956    3
# 01.12.1986    3
# 17.08.1992    3
# 14.02.1990    3
# 22.05.1976    3
# 25.04.1985    3
# 05.07.1986    3
# 19.11.1973    3
# 24.02.1955    3
# 27.01.1991    3
# 14.02.1991    3
# 06.05.1965    3
# 07.03.1993    3
# 10.09.1989    3
# 23.08.1995    3
# 18.06.1979    3
# 30.08.1995    3
# 07.10.1989    3
# 05.05.1985    3
# 18.09.1988    3
# 20.01.1974    3
# 01.08.1988    3
# 09.09.1991    3
# 08.09.1963    3
# 25.08.1989    3
# 05.04.1953    3
# 25.11.1984    3
# 23.08.1965    3
# 09.02.1977    3
# 05.02.1991    3
# Name: Дата рождения, dtype: int64

# %%
quantity = data['Наличие прикрепленных файлов'].value_counts()
print(quantity[0:2])
# Out:
# -    3870
# +     808
# Name: Наличие прикрепленных файлов, dtype: int64
